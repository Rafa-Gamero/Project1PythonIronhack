# %% [markdown]
# Aqui hemos creado las diferentes habitaciones y  objetos que vamos a necesitar. Asi como la importacion de las funciones que vamos a necesitar para poder utilizar el juego

# %%
# define rooms and items
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/Functions')
 
from EscapeRoomFunctions import *

# define rooms and items
# Game Room
secret_word = "abracadabra"

couch = {
    "name": "couch",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

piano = {
    "name": "piano",
    "type": "furniture",
}

game_room = {
    "name": "game room",
    "type": "room",
}

# Outside

door_d = {
    "name": "door d",
    "type": "door",
}
outside = {
    "name": "outside",
    "type": "room",
}

# Habitación 1

bedroom1 = {
    "name": "bedroom1",
    "type": "room",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

door_c = {
    "name": "door c",
    "type": "door",
}

queenbed = {
    "name": "queen bed",
    "type": "furniture",
}
# Habitación 2

bedroom2 = {
    "name": "bedroom2",
    "type": "room",
}

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}





# Living Room

livingroom = {
    "name": "living room",
    "type": "room",
}

dining_table = {
    "name": "dining table",
    "type": "furniture",
}
door_d = {
    "name": "door d",
    "type": "door",
}

all_rooms = [game_room, bedroom1, bedroom2, livingroom, outside]

all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "door a": [game_room, bedroom1],

    "bedroom1": [queenbed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "door b": [bedroom1, bedroom2],

    "bedroom2": [double_bed, dresser, door_b],
    "double bed": [key_c],
    "dresser": [],
    "door c": [bedroom1, livingroom],

    "living room": [dining_table, door_c, door_d],
    "dining table": [],
    "door d": [livingroom, outside],

    "outside": [door_d]
}


# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}



game_state = INIT_GAME_STATE.copy()

start_game(game_state)
